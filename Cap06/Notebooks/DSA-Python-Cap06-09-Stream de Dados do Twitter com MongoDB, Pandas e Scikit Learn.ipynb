# %% [markdown]
# # <font color='blue'>Data Science Academy - Python Fundamentos - Capítulo 6</font>
#
# ## Download: http://github.com/dsacademybr

# %% [markdown]
# ## Stream de Dados do Twitter com MongoDB, Pandas e Scikit Learn

# %% [markdown]
# ## Preparando a Conexão com o Twitter

# %%
# Instala o pacote tweepy
# !pip install tweepy
# Out:
# Collecting tweepy
#   Downloading https://files.pythonhosted.org/packages/36/1b/2bd38043d22ade352fc3d3902cf30ce0e2f4bf285be3b304a2782a767aec/tweepy-3.8.0-py2.py3-none-any.whl
# Requirement already satisfied: PySocks>=1.5.7 in c:\users\paula_oliveira\anaconda3\lib\site-packages (from tweepy) (1.6.8)
# Requirement already satisfied: six>=1.10.0 in c:\users\paula_oliveira\anaconda3\lib\site-packages (from tweepy) (1.12.0)
# Requirement already satisfied: requests>=2.11.1 in c:\users\paula_oliveira\anaconda3\lib\site-packages (from tweepy) (2.21.0)
# Collecting requests-oauthlib>=0.7.0 (from tweepy)
#   Downloading https://files.pythonhosted.org/packages/c2/e2/9fd03d55ffb70fe51f587f20bcf407a6927eb121de86928b34d162f0b1ac/requests_oauthlib-1.2.0-py2.py3-none-any.whl
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\paula_oliveira\anaconda3\lib\site-packages (from requests>=2.11.1->tweepy) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\paula_oliveira\anaconda3\lib\site-packages (from requests>=2.11.1->tweepy) (2.8)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in c:\users\paula_oliveira\anaconda3\lib\site-packages (from requests>=2.11.1->tweepy) (1.24.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\paula_oliveira\anaconda3\lib\site-packages (from requests>=2.11.1->tweepy) (2019.3.9)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib>=0.7.0->tweepy)
#   Downloading https://files.pythonhosted.org/packages/58/5e/289e98ff5ad1a321945803000c5f10f5f90eba346d13139ecdd075cfbe17/oauthlib-3.0.2-py2.py3-none-any.whl (143kB)
# Installing collected packages: oauthlib, requests-oauthlib, tweepy
# Successfully installed oauthlib-3.0.2 requests-oauthlib-1.2.0 tweepy-3.8.0

# %%
# Importando os módulos Tweepy, Datetime e Json
from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from tweepy import Stream
from datetime import datetime
import json

# %% [markdown]
# Veja no manual em pdf como criar sua API no Twitter e configure as suas chaves abaixo.

# %%
# Adicione aqui sua Consumer Key
consumer_key = "KraBRswKIIqAVL6zF48zBx8pU"

# %%
# Adicione aqui sua Consumer Secret 
consumer_secret = "2DrXFLdfsMNmigJX4OBEuK7vEYTtiPRvBhcdsGuMfURN6Kpfzf"

# %%
# Adicione aqui seu Access Token
access_token = "1153783824414887936-dgQR6OD7DZZEBUUe8Du3S2QKf2CA46"

# %%
# Adicione aqui seu Access Token Secret
access_token_secret = "KhNyOTMcmcZjbTAUXuouxWJK0VOfrnK9qDVDFqHLSgbHi"

# %%
# Criando as chaves de autenticação
auth = OAuthHandler(consumer_key, consumer_secret)

# %%
auth.set_access_token(access_token, access_token_secret)

# %%
# Criando uma classe para capturar os stream de dados do Twitter e 
# armazenar no MongoDB
class MyListener(StreamListener):
    def on_data(self, dados):
        tweet = json.loads(dados)
        created_at = tweet["created_at"]
        id_str = tweet["id_str"]
        text = tweet["text"]
        obj = {"created_at":created_at,"id_str":id_str,"text":text,}
        tweetind = col.insert_one(obj).inserted_id
        print (obj)
        return True

# %%
# Criando o objeto mylistener
mylistener = MyListener()

# %%
# Criando o objeto mystream
mystream = Stream(auth, listener = mylistener)

# %% [markdown]
# ## Preparando a Conexão com o MongoDB

# %%
# Importando do PyMongo o módulo MongoClient
from pymongo import MongoClient

# %%
# Criando a conexão ao MongoDB
client = MongoClient('localhost', 27017)

# %%
# Criando o banco de dados twitterdb
db = client.twitterdb

# %%
# Criando a collection "col"
col = db.tweets

# %%
# Criando uma lista de palavras chave para buscar nos Tweets
keywords = ['Big Data', 'Python', 'Data Mining', 'Data Science']

# %% [markdown]
# ## Coletando os Tweets

# %%
# Iniciando o filtro e gravando os tweets no MongoDB
mystream.filter(track=keywords)
# Out:
# {'created_at': 'Wed Jul 24 00:59:32 +0000 2019', 'id_str': '1153832050614341632', 'text': 'Mi nuh like hypocrite an bad mine people data y mi stay to miself 99.9% a di time di 1% know how di draggins guh bi… https://t.co/8WV7i8D6qo', '_id': ObjectId('5d37ad7a468a70c5dd9d9243')}
# {'created_at': 'Wed Jul 24 00:59:35 +0000 2019', 'id_str': '1153832061372776449', 'text': "RT @WesternBhagwa: @SulagnaDash6 Reminded me of 'Pau kilo ka python' from Golmaal fun unlimited 😅", '_id': ObjectId('5d37ad7c468a70c5dd9d9244')}
# {'created_at': 'Wed Jul 24 00:59:36 +0000 2019', 'id_str': '1153832065479008256', 'text': "@TheAmolWalvekar @wimlds Yes. Here's the link to RSVP: https://t.co/fQKNP0iFLN", '_id': ObjectId('5d37ad7d468a70c5dd9d9245')}
# {'created_at': 'Wed Jul 24 00:59:38 +0000 2019', 'id_str': '1153832072924082176', 'text': 'RT @KingMidasAu1: $SNMN massive inflection of buying,expect a big break out with news\n\nhttps://t.co/kSsHgajXVz\n\n$AMRN $KBLB $LAHO $DCGD $FN…', '_id': ObjectId('5d37ad7f468a70c5dd9d9246')}
# {'created_at': 'Wed Jul 24 00:59:40 +0000 2019', 'id_str': '1153832082348470276', 'text': 'RT @jimbobbennett: Well this is a no brainer - @github is involved in a lot of student Hackathons and this data shows how beneficial they a…', '_id': ObjectId('5d37ad81468a70c5dd9d9247')}
# {'created_at': 'Wed Jul 24 00:59:47 +0000 2019', 'id_str': '1153832113872896003', 'text': 'RT @zakkie_jp: “AIエバンジェリスト、ＡＩ 駆動ビジネス、Python、Agile、Scrumは株式会社アークの登録商標です”&lt; 法的には問題ないが、社会通念的にアウトだろ。 / “日本初！ ＡＩをビジネスに直結させる\u3000【ＡＩ駆動ビジネス塾】 \u3000” https:…', '_id': ObjectId('5d37ad89468a70c5dd9d9248')}
# {'created_at': 'Wed Jul 24 00:59:49 +0000 2019', 'id_str': '1153832122638950401', 'text': 'RT @odsc: MIT Press and Harvard Data Science Initiative launch the Harvard Data Science Review. #DataScience #AI #ArtificialIntelligence #B…', '_id': ObjectId('5d37ad8b468a70c5dd9d9249')}
# {'created_at': 'Wed Jul 24 00:59:51 +0000 2019', 'id_str': '1153832128393568256', 'text': 'RT @simizu706: 分析だけならRでいいと思います。ただ、最近の心理学実験のプログラムがPythonで動くものが多いです。その場合、Pythonができたほうがいいだろうな、と。そして…\n\n続きは質問箱へ (残り 49字) \n\n#peing #質問箱 https://t…', '_id': ObjectId('5d37ad8c468a70c5dd9d924a')}
# {'created_at': 'Wed Jul 24 00:59:53 +0000 2019', 'id_str': '1153832138250129415', 'text': '@QL611 @hrenee80 So I have a multi-colored Ball Python.....where do I stand?', '_id': ObjectId('5d37ad8f468a70c5dd9d924b')}
# {'created_at': 'Wed Jul 24 00:59:54 +0000 2019', 'id_str': '1153832141119115264', 'text': 'Only 5 months 7 days 23 hours left until Python 2 retires', '_id': ObjectId('5d37ad8f468a70c5dd9d924c')}
# {'created_at': 'Wed Jul 24 01:00:00 +0000 2019', 'id_str': '1153832166205190145', 'text': '【2018年Google Trends調べ】\n最もググられたプログラミング言語ベスト10\n\n1. JavaScript \n2. Python \n3. Java\n4. Go\n5. Elixir\n6. Ruby\n7. Kotlin\n8… https://t.co/NrFydbIDjL', '_id': ObjectId('5d37ad95468a70c5dd9d924d')}
# {'created_at': 'Wed Jul 24 01:00:02 +0000 2019', 'id_str': '1153832175457820673', 'text': 'Hosting (Hospedaje Web) Premium 99.99% Uptime, cPanel, Soporte 24/7, Backups, Python, Ruby, Php, MySql, Cms´s, Softaculous, -hostxido.com', '_id': ObjectId('5d37ad97468a70c5dd9d924e')}
# {'created_at': 'Wed Jul 24 01:00:02 +0000 2019', 'id_str': '1153832176569348096', 'text': 'RT @AxBernardes: MATLAB é muito prático, mas tem horas que ele enche tanto o saco que dá vontade de migrar toda a pesquisa pra python. Aí s…', '_id': ObjectId('5d37ad98468a70c5dd9d924f')}
# {'created_at': 'Wed Jul 24 01:00:03 +0000 2019', 'id_str': '1153832178725208068', 'text': 'RT @ubuntu_sec: Episode 40 of the @Ubuntu #Security Podcast is live - covers the past 2 weeks security including @Docker, @zeromq, Squid, @…', '_id': ObjectId('5d37ad98468a70c5dd9d9250')}
# {'created_at': 'Wed Jul 24 01:00:03 +0000 2019', 'id_str': '1153832178591174657', 'text': 'This job opening may be your career booster =&gt; Big Data Systems Administrator https://t.co/PXisLmzBCy #bigdata #iot… https://t.co/B53qXkRCFG', '_id': ObjectId('5d37ad98468a70c5dd9d9251')}
# {'created_at': 'Wed Jul 24 01:00:03 +0000 2019', 'id_str': '1153832179316772865', 'text': 'RT @DTaC_BOT: Imagine how useful Python code would be for being a glazier. Langdon Winner might even say such a use would be unimaginative!', '_id': ObjectId('5d37ad99468a70c5dd9d9252')}
# {'created_at': 'Wed Jul 24 01:00:03 +0000 2019', 'id_str': '1153832181032194048', 'text': 'RT @richhinkle: This would be fun to try with process Historian data.  \nTime Series Decomposition &amp; Prediction in Python https://t.co/jm9Q3…', '_id': ObjectId('5d37ad99468a70c5dd9d9253')}
# {'created_at': 'Wed Jul 24 01:00:04 +0000 2019', 'id_str': '1153832183011786753', 'text': 'RT @pythonlangbot: Is there a 1-line solution to turn a scalar into a n-length array with the same value in each element https://t.co/YySfd…', '_id': ObjectId('5d37ad99468a70c5dd9d9254')}
# {'created_at': 'Wed Jul 24 01:00:04 +0000 2019', 'id_str': '1153832184945545216', 'text': 'RT @simizu706: 分析だけならRでいいと思います。ただ、最近の心理学実験のプログラムがPythonで動くものが多いです。その場合、Pythonができたほうがいいだろうな、と。そして…\n\n続きは質問箱へ (残り 49字) \n\n#peing #質問箱 https://t…', '_id': ObjectId('5d37ad9a468a70c5dd9d9255')}
# {'created_at': 'Wed Jul 24 01:00:05 +0000 2019', 'id_str': '1153832187558371330', 'text': 'RT @blackcat_syka: 日本語学概論、突然pythonコード見せ始めてわろてる', '_id': ObjectId('5d37ad9a468a70c5dd9d9256')}
# {'created_at': 'Wed Jul 24 01:00:05 +0000 2019', 'id_str': '1153832187793301504', 'text': 'RT @pythonlangbot: Is there a 1-line solution to turn a scalar into a n-length array with the same value in each element https://t.co/YySfd…', '_id': ObjectId('5d37ad9a468a70c5dd9d9257')}
# {'created_at': 'Wed Jul 24 01:00:05 +0000 2019', 'id_str': '1153832189819117568', 'text': 'A big thank you to @RM_Furey for coming out and teaching a TVLI class about data! People are excited to use the bes… https://t.co/gjbrUWkNOn', '_id': ObjectId('5d37ad9c468a70c5dd9d9258')}
# {'created_at': 'Wed Jul 24 01:00:10 +0000 2019', 'id_str': '1153832210077761538', 'text': 'All still avalable', '_id': ObjectId('5d37ada0468a70c5dd9d9259')}
# {'created_at': 'Wed Jul 24 01:00:12 +0000 2019', 'id_str': '1153832217170235393', 'text': "@ryanallred I think Observable https://t.co/pK3wB6JFJn can be embedded in any site, but then you're dealing with JS and not Python 😕", '_id': ObjectId('5d37ada2468a70c5dd9d925a')}
# {'created_at': 'Wed Jul 24 01:00:12 +0000 2019', 'id_str': '1153832217807740930', 'text': 'Review: Be afraid. Be very afraid of big data. The documentary ‘The Great Hack’ tells us why… https://t.co/1dIBEESmgX', '_id': ObjectId('5d37ada2468a70c5dd9d925b')}
# {'created_at': 'Wed Jul 24 01:00:12 +0000 2019', 'id_str': '1153832218000625670', 'text': 'Is Boris Johnson not a Monty python character?', '_id': ObjectId('5d37ada2468a70c5dd9d925c')}
# {'created_at': 'Wed Jul 24 01:00:12 +0000 2019', 'id_str': '1153832217644109826', 'text': 'ラズベリーパイより、7月24日10時0分の空模様と気温 25.625℃ #raspberrypi #python #fswebcam #photo #北海道 #オホーツク #イマソラ https://t.co/ytGOF6NgYS', '_id': ObjectId('5d37ada2468a70c5dd9d925d')}
# {'created_at': 'Wed Jul 24 01:00:13 +0000 2019', 'id_str': '1153832220462735360', 'text': '#EulerOS #2.0 SP2 : python-jinja2 (EulerOS-SA-2019-1722) https://t.co/zJH8Wh3phN #Nessus', '_id': ObjectId('5d37ada2468a70c5dd9d925e')}
# {'created_at': 'Wed Jul 24 01:00:13 +0000 2019', 'id_str': '1153832223482605568', 'text': 'RT @pythonlangbot: Is there a 1-line solution to turn a scalar into a n-length array with the same value in each element https://t.co/YySfd…', '_id': ObjectId('5d37ada3468a70c5dd9d925f')}
# {'created_at': 'Wed Jul 24 01:00:15 +0000 2019', 'id_str': '1153832228474036224', 'text': 'Hey did you know I was born at Studio Bas Sala ? They love Big Data too ! #BigData #StudioBasSala', '_id': ObjectId('5d37ada4468a70c5dd9d9260')}
# {'created_at': 'Wed Jul 24 01:00:15 +0000 2019', 'id_str': '1153832228792627201', 'text': 'Everyone needs to use @whispersystems #Signal right the fuck now.', '_id': ObjectId('5d37ada4468a70c5dd9d9261')}
# {'created_at': 'Wed Jul 24 01:00:15 +0000 2019', 'id_str': '1153832229228838912', 'text': 'This is the Big Data Furniture. I will be colleting the data of the #Dutch DesignWeek visitors. You can find me at… https://t.co/oAaWORkPmj', '_id': ObjectId('5d37ada4468a70c5dd9d9262')}
# {'created_at': 'Wed Jul 24 01:00:15 +0000 2019', 'id_str': '1153832230193643525', 'text': 'Data + Data + Data makes Big Data #BigData #DDW16', '_id': ObjectId('5d37ada5468a70c5dd9d9263')}
# {'created_at': 'Wed Jul 24 01:00:18 +0000 2019', 'id_str': '1153832244743565312', 'text': 'This AI Can Transform Your Photos Into A Renaissance Masterpiece https://t.co/JXvTjayNh8 #DeepLearning… https://t.co/0Fmxtk6L0L', '_id': ObjectId('5d37ada8468a70c5dd9d9264')}
# {'created_at': 'Wed Jul 24 01:00:19 +0000 2019', 'id_str': '1153832246031179777', 'text': 'RT @suin: Pythonって商標登録されてたんですね…。\n\n言語としての商標ではなく、セミナー等に限ってのもののようですが、公の財産とも言えるオープンソースのプロダクト名を商標登録しちゃうのってどうなんでしょう🤔\n\nサイトの注意書きを見る限り、競合他社のPython講座…', '_id': ObjectId('5d37ada8468a70c5dd9d9265')}
# {'created_at': 'Wed Jul 24 01:00:19 +0000 2019', 'id_str': '1153832247864152065', 'text': 'RT @Bradley_Dice: @EricJorgenson I wrote some guest lectures on Databases for a chemical engineering graduate course. It uses Python + SQLi…', '_id': ObjectId('5d37ada9468a70c5dd9d9266')}
# {'created_at': 'Wed Jul 24 01:00:20 +0000 2019', 'id_str': '1153832251131432960', 'text': 'RT @realpython: 🐍🎤 Python Community Interview With Mike Grouchy — https://t.co/t2WmtHWRro https://t.co/cYNTKjEc5O', '_id': ObjectId('5d37adaa468a70c5dd9d9267')}
# {'created_at': 'Wed Jul 24 01:00:20 +0000 2019', 'id_str': '1153832253115363328', 'text': 'RT @blackcat_syka: 日本語学概論、突然pythonコード見せ始めてわろてる', '_id': ObjectId('5d37adaa468a70c5dd9d9268')}
# {'created_at': 'Wed Jul 24 01:00:21 +0000 2019', 'id_str': '1153832255518720000', 'text': "RT @SBace6: @stonecold2050 Monty Python couldn't write a script this ridiculous. 😂☺️😂☺️😂", '_id': ObjectId('5d37adab468a70c5dd9d9269')}
# {'created_at': 'Wed Jul 24 01:00:26 +0000 2019', 'id_str': '1153832275055800321', 'text': 'AVAILABLE: Python: 2 Manuscripts in 1 book : -  Python For... by Timothy C. Needham - https://t.co/fGSqrhtNJ1', '_id': ObjectId('5d37adaf468a70c5dd9d926a')}
# {'created_at': 'Wed Jul 24 01:00:26 +0000 2019', 'id_str': '1153832277182308352', 'text': '@HolyCarpSC @incendiate Oh big derp, I miss-read the frame data there.', '_id': ObjectId('5d37adb0468a70c5dd9d926b')}
# {'created_at': 'Wed Jul 24 01:00:26 +0000 2019', 'id_str': '1153832277866090498', 'text': 'RT @mattblaze: I have to say, Barr’s argument that the personal and commercial data protected by encryption isn’t all that important and th…', '_id': ObjectId('5d37adb0468a70c5dd9d926c')}
# {'created_at': 'Wed Jul 24 01:00:27 +0000 2019', 'id_str': '1153832280965562368', 'text': '#Spectrum My #InternetSpeed :\nPing: 44.305 ms\nDownload: 176.23 Mbit/s\nUpload: 11.06 Mbit/s\n#automagic #python #corporateaccountability', '_id': ObjectId('5d37adb1468a70c5dd9d926d')}
# {'created_at': 'Wed Jul 24 01:00:28 +0000 2019', 'id_str': '1153832282949586944', 'text': 'What is your story of being locked in a company with a bad or nonexistent data science culture, and how did you mak… https://t.co/xH72Doe6O9', '_id': ObjectId('5d37adb1468a70c5dd9d926e')}
# {'created_at': 'Wed Jul 24 01:00:30 +0000 2019', 'id_str': '1153832294517563392', 'text': 'RT @cloudpreacher: The Chief Data Officer role was created in response to Big Data as companies accumulated ever-growing stores of data, so…', '_id': ObjectId('5d37adb4468a70c5dd9d926f')}
# {'created_at': 'Wed Jul 24 01:00:32 +0000 2019', 'id_str': '1153832299709919232', 'text': '#Trending: How to get a job working with artificial intelligence/machine learning - The Next Web\n\n#pyton #python… https://t.co/5hvhupzF9g', '_id': ObjectId('5d37adb5468a70c5dd9d9270')}
# {'created_at': 'Wed Jul 24 01:00:32 +0000 2019', 'id_str': '1153832300364177408', 'text': '今回はPythonのwhile文について解説しました！\n\n繰り返し処理は非常に頻繁に使われる処理でもあるので、\n初心者も必ず覚えておいていただければと思います。\n\nぜひご一読ください！… https://t.co/8TU8mOpJsW', '_id': ObjectId('5d37adb5468a70c5dd9d9271')}
# {'created_at': 'Wed Jul 24 01:00:32 +0000 2019', 'id_str': '1153832301014294530', 'text': "RT @pujaarajan: @TheAmolWalvekar @wimlds Yes. Here's the link to RSVP: https://t.co/fQKNP0iFLN", '_id': ObjectId('5d37adb5468a70c5dd9d9272')}
# {'created_at': 'Wed Jul 24 01:00:33 +0000 2019', 'id_str': '1153832304759853056', 'text': 'RT @python_import: A range filter and median filter using python https://t.co/C48FyaWFi6 Design a basic filter using numpy library in pytho…', '_id': ObjectId('5d37adb6468a70c5dd9d9273')}
# {'created_at': 'Wed Jul 24 01:00:33 +0000 2019', 'id_str': '1153832307054092288', 'text': "@biopharmacaster OMG, you really don't understand the data.  These were good results.  On Pancreatic cancer, nothin… https://t.co/Fcqxq42Zgx", '_id': ObjectId('5d37adb7468a70c5dd9d9274')}
# {'created_at': 'Wed Jul 24 01:00:34 +0000 2019', 'id_str': '1153832309868486657', 'text': 'RT @DynamoBIM: Come explore what Dynamo Core release 2.2 has to offer in our latest blog post! The Python node gets some polish with specia…', '_id': ObjectId('5d37adb8468a70c5dd9d9275')}
# {'created_at': 'Wed Jul 24 01:00:34 +0000 2019', 'id_str': '1153832309205790720', 'text': 'Onboard in one week-3 months contract #Python programmer opportunity - [ ➡ https://t.co/TUiKHN7y4g ] #Robotics #AI… https://t.co/0EZxuZMAZX', '_id': ObjectId('5d37adb8468a70c5dd9d9276')}
# {'created_at': 'Wed Jul 24 01:00:34 +0000 2019', 'id_str': '1153832310346678274', 'text': "RT @emekaboris: You shouldn't miss this if you are in Port Harcourt.\n\nWe will discuss best practice and new technologies for Data Science,…", '_id': ObjectId('5d37adb8468a70c5dd9d9277')}
# {'created_at': 'Wed Jul 24 01:00:35 +0000 2019', 'id_str': '1153832316101414912', 'text': 'Our Python Pupil Activity Pack teaches the programming language of Python (used by Facebook, Instagram, NASA, Youtu… https://t.co/kjzBW0dUC1', '_id': ObjectId('5d37adb9468a70c5dd9d9278')}
# {'created_at': 'Wed Jul 24 01:00:37 +0000 2019', 'id_str': '1153832323579703297', 'text': 'RT @Deep_In_Depth: Deep learning distinguishes Alzheimer’s from normal cognition https://t.co/4oH4yJEPS3 #DeepLearning #MachineLearning #AI…', '_id': ObjectId('5d37adbb468a70c5dd9d9279')}
# {'created_at': 'Wed Jul 24 01:00:38 +0000 2019', 'id_str': '1153832325098201088', 'text': '@MisturSanjay Rabbit the brown swallowed the female python whole', '_id': ObjectId('5d37adbb468a70c5dd9d927a')}
# {'created_at': 'Wed Jul 24 01:00:40 +0000 2019', 'id_str': '1153832333730025472', 'text': 'Great work @MarkFredNubble @briancreagan!', '_id': ObjectId('5d37adbd468a70c5dd9d927b')}
# {'created_at': 'Wed Jul 24 01:00:41 +0000 2019', 'id_str': '1153832339912347648', 'text': 'How to keep track of tools and equipment. What data and systems do you need to keep track of your assets, machines,… https://t.co/BQvQbjhZ6N', '_id': ObjectId('5d37adbf468a70c5dd9d927c')}
# {'created_at': 'Wed Jul 24 01:00:51 +0000 2019', 'id_str': '1153832379569414144', 'text': 'Advanced Machine Learning with Basic Excel. #Analytics #Data #BusinessIntelligence #DataScience… https://t.co/Lf413d7Vwe', '_id': ObjectId('5d37adc8468a70c5dd9d927d')}
# {'created_at': 'Wed Jul 24 01:00:53 +0000 2019', 'id_str': '1153832391229657091', 'text': '10 Predictions For AI, Big Data, And Analytics In 2018 For many businesses, technology seems to cause more problems https://t.co/7oR8pCvTwO', '_id': ObjectId('5d37adcb468a70c5dd9d927e')}
# {'created_at': 'Wed Jul 24 01:01:04 +0000 2019', 'id_str': '1153832433659215873', 'text': 'RT @mattblaze: I have to say, Barr’s argument that the personal and commercial data protected by encryption isn’t all that important and th…', '_id': ObjectId('5d37add5468a70c5dd9d927f')}
# {'created_at': 'Wed Jul 24 01:01:06 +0000 2019', 'id_str': '1153832442702303232', 'text': 'RT @Deep__AI: From the Machine Learning &amp; Data Science glossary: Anomaly Detection https://t.co/SLVG6qw87Y #SupportVectorMachine #AnomalyDe…', '_id': ObjectId('5d37add7468a70c5dd9d9280')}
# {'created_at': 'Wed Jul 24 01:01:06 +0000 2019', 'id_str': '1153832444266786816', 'text': '@LucylleR Merci pour m\'avoir mis un sketch des monty python dans la gueule grace à ta blague!\n"Sit on my face and t… https://t.co/OuaEmQytVN', '_id': ObjectId('5d37add8468a70c5dd9d9281')}
# {'created_at': 'Wed Jul 24 01:01:09 +0000 2019', 'id_str': '1153832457004703745', 'text': 'Deep learning distinguishes Alzheimer’s from normal cognition https://t.co/GbdR5bj4is #DeepLearning… https://t.co/Lj81GpRnuk', '_id': ObjectId('5d37addb468a70c5dd9d9282')}
# {'created_at': 'Wed Jul 24 01:01:12 +0000 2019', 'id_str': '1153832467981168640', 'text': 'Causality is a very flawed practice...how does Big Data predict?\nhttps://t.co/oC8nufs1CD', '_id': ObjectId('5d37addd468a70c5dd9d9283')}
# {'created_at': 'Wed Jul 24 01:01:14 +0000 2019', 'id_str': '1153832478978822145', 'text': "RT @DaniellesCave: Big new research project from @ASPI_ICPC we've just put online. We combined open-source data with the collection and ana…", '_id': ObjectId('5d37ade0468a70c5dd9d9284')}
# {'created_at': 'Wed Jul 24 01:01:16 +0000 2019', 'id_str': '1153832484980740096', 'text': '@therealmonaIisa Python is a great beginner friendly language and it is widely used in a variety of fields.', '_id': ObjectId('5d37ade1468a70c5dd9d9285')}
# {'created_at': 'Wed Jul 24 01:01:18 +0000 2019', 'id_str': '1153832494489190400', 'text': 'RT @mattblaze: I have to say, Barr’s argument that the personal and commercial data protected by encryption isn’t all that important and th…', '_id': ObjectId('5d37ade4468a70c5dd9d9286')}
# {'created_at': 'Wed Jul 24 01:01:24 +0000 2019', 'id_str': '1153832518321364992', 'text': 'RT @LouisVillacci: A big thank you to @RM_Furey for coming out and teaching a TVLI class about data! People are excited to use the best dat…', '_id': ObjectId('5d37ade9468a70c5dd9d9287')}
# {'created_at': 'Wed Jul 24 01:01:27 +0000 2019', 'id_str': '1153832531839426560', 'text': '@nando_nurhadi @yuswohady @jams_ksei @fitriyanojik @bro_danang @pirenaningsih Mungkin ini asal muasal istilah big d… https://t.co/n5jZHoa49i', '_id': ObjectId('5d37aded468a70c5dd9d9288')}
# {'created_at': 'Wed Jul 24 01:01:28 +0000 2019', 'id_str': '1153832537027801089', 'text': 'Job : AI &amp; MACHINE LEARNING ENGINEER\nLocation: Plaza Damas 3, Kuala Lumpur\nAt least 2 years of experience in AI and… https://t.co/khG6D6rIEV', '_id': ObjectId('5d37adee468a70c5dd9d9289')}
# {'created_at': 'Wed Jul 24 01:01:35 +0000 2019', 'id_str': '1153832563984805888', 'text': 'RT @KirkDBorne: 5 Books on #AI and #MachineLearning to get in 2019: https://t.co/VYFynmubzO #abdsc #DataScience #BigData #Python #Reinforce…', '_id': ObjectId('5d37adf4468a70c5dd9d928a')}
# {'created_at': 'Wed Jul 24 01:01:37 +0000 2019', 'id_str': '1153832574558572544', 'text': 'RT @mattblaze: I have to say, Barr’s argument that the personal and commercial data protected by encryption isn’t all that important and th…', '_id': ObjectId('5d37adf7468a70c5dd9d928b')}
# {'created_at': 'Wed Jul 24 01:01:39 +0000 2019', 'id_str': '1153832581034467330', 'text': 'Python for Data Science: 8 Concepts You May Have Forgotten\n\n☞ https://t.co/6cQlkYvJVe\n\n#python #programming https://t.co/Delke1TKSd', '_id': ObjectId('5d37adf8468a70c5dd9d928c')}
# {'created_at': 'Wed Jul 24 01:01:45 +0000 2019', 'id_str': '1153832609086169088', 'text': 'RT @vakibs: My mother tongue Telugu will disappear in a few decades. It already became a pidgin of English. On TV, barely anyone can speak…', '_id': ObjectId('5d37adff468a70c5dd9d928d')}
# {'created_at': 'Wed Jul 24 01:01:49 +0000 2019', 'id_str': '1153832624365772800', 'text': 'RT @sntripathi1: Businesses are changing the way they engage with customers and manage customers &amp; customer service teams by driving innova…', '_id': ObjectId('5d37ae02468a70c5dd9d928e')}
# {'created_at': 'Wed Jul 24 01:01:51 +0000 2019', 'id_str': '1153832632427274240', 'text': 'RT @Rbloggers: Learning Data Science: Understanding and Using k-means Clustering  {https://t.co/vVltNVZO0v} #rstats #DataScience', '_id': ObjectId('5d37ae04468a70c5dd9d928f')}
# {'created_at': 'Wed Jul 24 01:01:59 +0000 2019', 'id_str': '1153832667814645761', 'text': 'RT @mattblaze: I have to say, Barr’s argument that the personal and commercial data protected by encryption isn’t all that important and th…', '_id': ObjectId('5d37ae0d468a70c5dd9d9290')}
# {'created_at': 'Wed Jul 24 01:02:01 +0000 2019', 'id_str': '1153832676790558721', 'text': 'Download The Art of Invisibility: The World&amp;#39;s Most Famous Hacker Teaches You How to Be Safe in the Age of Big B… https://t.co/ctXsABnWjX', '_id': ObjectId('5d37ae0f468a70c5dd9d9291')}
# {'created_at': 'Wed Jul 24 01:02:04 +0000 2019', 'id_str': '1153832687548940297', 'text': 'RT @himpatani: วิชาวิทยการคำนวณ วิชาใหม่สำหรับเด็กไทยและครูไทยทุกคน\n\n#วิทยาการคำนวณ #python\nhttps://t.co/wJJgi2GWmg', '_id': ObjectId('5d37ae11468a70c5dd9d9292')}
# ---------------------------------------------------------------------------
# WantReadError                             Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     293         try:
# --> 294             return self.connection.recv_into(*args, **kwargs)
#     295         except OpenSSL.SSL.SysCallError as e:
#
# ~\Anaconda3\lib\site-packages\OpenSSL\SSL.py in recv_into(self, buffer, nbytes, flags)
#    1821             result = _lib.SSL_read(self._ssl, buf, nbytes)
# -> 1822         self._raise_ssl_error(self._ssl, result)
#    1823
#
# ~\Anaconda3\lib\site-packages\OpenSSL\SSL.py in _raise_ssl_error(self, ssl, result)
#    1621         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1622             raise WantReadError()
#    1623         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-6a9070444200> in <module>
#       1 # Iniciando o filtro e gravando os tweets no MongoDB
# ----> 2 mystream.filter(track=keywords)
#
# ~\Anaconda3\lib\site-packages\tweepy\streaming.py in filter(self, follow, track, is_async, locations, stall_warnings, languages, encoding, filter_level)
#     472             self.body['filter_level'] = filter_level.encode(encoding)
#     473         self.session.params = {'delimited': 'length'}
# --> 474         self._start(is_async)
#     475
#     476     def sitestream(self, follow, stall_warnings=False,
#
# ~\Anaconda3\lib\site-packages\tweepy\streaming.py in _start(self, is_async)
#     387             self._thread.start()
#     388         else:
# --> 389             self._run()
#     390
#     391     def on_closed(self, resp):
#
# ~\Anaconda3\lib\site-packages\tweepy\streaming.py in _run(self)
#     287                     self.snooze_time = self.snooze_time_step
#     288                     self.listener.on_connect()
# --> 289                     self._read_loop(resp)
#     290             except (Timeout, ssl.SSLError) as exc:
#     291                 # This is still necessary, as a SSLError can actually be
#
# ~\Anaconda3\lib\site-packages\tweepy\streaming.py in _read_loop(self, resp)
#     337             length = 0
#     338             while not resp.raw.closed:
# --> 339                 line = buf.read_line()
#     340                 stripped_line = line.strip() if line else line # line is sometimes None so we need to check here
#     341                 if not stripped_line:
#
# ~\Anaconda3\lib\site-packages\tweepy\streaming.py in read_line(self, sep)
#     198             else:
#     199                 start = len(self._buffer)
# --> 200             self._buffer += self._stream.read(self._chunk_size)
#     201         return six.b('')
#     202
#
# ~\Anaconda3\lib\site-packages\urllib3\response.py in read(self, amt, decode_content, cache_content)
#     440             else:
#     441                 cache_content = False
# --> 442                 data = self._fp.read(amt)
#     443                 if amt != 0 and not data:  # Platform-specific: Buggy versions of Python.
#     444                     # Close the connection when no data is returned
#
# ~\Anaconda3\lib\http\client.py in read(self, amt)
#     445             # Amount is given, implement using readinto
#     446             b = bytearray(amt)
# --> 447             n = self.readinto(b)
#     448             return memoryview(b)[:n].tobytes()
#     449         else:
#
# ~\Anaconda3\lib\http\client.py in readinto(self, b)
#     479
#     480         if self.chunked:
# --> 481             return self._readinto_chunked(b)
#     482
#     483         if self.length is not None:
#
# ~\Anaconda3\lib\http\client.py in _readinto_chunked(self, b)
#     574         try:
#     575             while True:
# --> 576                 chunk_left = self._get_chunk_left()
#     577                 if chunk_left is None:
#     578                     return total_bytes
#
# ~\Anaconda3\lib\http\client.py in _get_chunk_left(self)
#     542                 self._safe_read(2)  # toss the CRLF at the end of the chunk
#     543             try:
# --> 544                 chunk_left = self._read_next_chunk_size()
#     545             except ValueError:
#     546                 raise IncompleteRead(b'')
#
# ~\Anaconda3\lib\http\client.py in _read_next_chunk_size(self)
#     502     def _read_next_chunk_size(self):
#     503         # Read the next chunk size from the file
# --> 504         line = self.fp.readline(_MAXLINE + 1)
#     505         if len(line) > _MAXLINE:
#     506             raise LineTooLong("chunk size")
#
# ~\Anaconda3\lib\socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# ~\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     304                 raise
#     305         except OpenSSL.SSL.WantReadError:
# --> 306             if not util.wait_for_read(self.socket, self.socket.gettimeout()):
#     307                 raise timeout('The read operation timed out')
#     308             else:
#
# ~\Anaconda3\lib\site-packages\urllib3\util\wait.py in wait_for_read(sock, timeout)
#     141     Returns True if the socket is readable, or False if the timeout expired.
#     142     """
# --> 143     return wait_for_socket(sock, read=True, timeout=timeout)
#     144
#     145
#
# ~\Anaconda3\lib\site-packages\urllib3\util\wait.py in select_wait_for_socket(sock, read, write, timeout)
#      81     # thing.)
#      82     fn = partial(select.select, rcheck, wcheck, wcheck)
# ---> 83     rready, wready, xready = _retry_on_intr(fn, timeout)
#      84     return bool(rready or wready or xready)
#      85
#
# ~\Anaconda3\lib\site-packages\urllib3\util\wait.py in _retry_on_intr(fn, timeout)
#      40     # Modern Python, that retries syscalls by default
#      41     def _retry_on_intr(fn, timeout):
# ---> 42         return fn(timeout)
#      43 else:
#      44     # Old and broken Pythons.
#
# KeyboardInterrupt:

# %% [markdown]
# ## --> Pressione o botão Stop na barra de ferramentas para encerrar a captura dos Tweets

# %% [markdown]
# ## Consultando os Dados no MongoDB

# %%
mystream.disconnect()

# %%
# Verificando um documento no collection
col.find_one()
# Out:
# {'_id': ObjectId('5d37ad7a468a70c5dd9d9243'),
#  'created_at': 'Wed Jul 24 00:59:32 +0000 2019',
#  'id_str': '1153832050614341632',
#  'text': 'Mi nuh like hypocrite an bad mine people data y mi stay to miself 99.9% a di time di 1% know how di draggins guh bi… https://t.co/8WV7i8D6qo'}

# %% [markdown]
# ## Análise de Dados com Pandas e Scikit-Learn

# %%
# criando um dataset com dados retornados do MongoDB
dataset = [{"created_at": item["created_at"], "text": item["text"],} for item in col.find()]

# %%
dataset
# Out:
# [{'created_at': 'Wed Jul 24 00:59:32 +0000 2019',
#   'text': 'Mi nuh like hypocrite an bad mine people data y mi stay to miself 99.9% a di time di 1% know how di draggins guh bi… https://t.co/8WV7i8D6qo'},
#  {'created_at': 'Wed Jul 24 00:59:35 +0000 2019',
#   'text': "RT @WesternBhagwa: @SulagnaDash6 Reminded me of 'Pau kilo ka python' from Golmaal fun unlimited 😅"},
#  {'created_at': 'Wed Jul 24 00:59:36 +0000 2019',
#   'text': "@TheAmolWalvekar @wimlds Yes. Here's the link to RSVP: https://t.co/fQKNP0iFLN"},
#  {'created_at': 'Wed Jul 24 00:59:38 +0000 2019',
#   'text': 'RT @KingMidasAu1: $SNMN massive inflection of buying,expect a big break out with news\n\nhttps://t.co/kSsHgajXVz\n\n$AMRN $KBLB $LAHO $DCGD $FN…'},
#  {'created_at': 'Wed Jul 24 00:59:40 +0000 2019',
#   'text': 'RT @jimbobbennett: Well this is a no brainer - @github is involved in a lot of student Hackathons and this data shows how beneficial they a…'},
#  {'created_at': 'Wed Jul 24 00:59:47 +0000 2019',
#   'text': 'RT @zakkie_jp: “AIエバンジェリスト、ＡＩ 駆動ビジネス、Python、Agile、Scrumは株式会社アークの登録商標です”&lt; 法的には問題ないが、社会通念的にアウトだろ。 / “日本初！ ＡＩをビジネスに直結させる\u3000【ＡＩ駆動ビジネス塾】 \u3000” https:…'},
#  {'created_at': 'Wed Jul 24 00:59:49 +0000 2019',
#   'text': 'RT @odsc: MIT Press and Harvard Data Science Initiative launch the Harvard Data Science Review. #DataScience #AI #ArtificialIntelligence #B…'},
#  {'created_at': 'Wed Jul 24 00:59:51 +0000 2019',
#   'text': 'RT @simizu706: 分析だけならRでいいと思います。ただ、最近の心理学実験のプログラムがPythonで動くものが多いです。その場合、Pythonができたほうがいいだろうな、と。そして…\n\n続きは質問箱へ (残り 49字) \n\n#peing #質問箱 https://t…'},
#  {'created_at': 'Wed Jul 24 00:59:53 +0000 2019',
#   'text': '@QL611 @hrenee80 So I have a multi-colored Ball Python.....where do I stand?'},
#  {'created_at': 'Wed Jul 24 00:59:54 +0000 2019',
#   'text': 'Only 5 months 7 days 23 hours left until Python 2 retires'},
#  {'created_at': 'Wed Jul 24 01:00:00 +0000 2019',
#   'text': '【2018年Google Trends調べ】\n最もググられたプログラミング言語ベスト10\n\n1. JavaScript \n2. Python \n3. Java\n4. Go\n5. Elixir\n6. Ruby\n7. Kotlin\n8… https://t.co/NrFydbIDjL'},
#  {'created_at': 'Wed Jul 24 01:00:02 +0000 2019',
#   'text': 'Hosting (Hospedaje Web) Premium 99.99% Uptime, cPanel, Soporte 24/7, Backups, Python, Ruby, Php, MySql, Cms´s, Softaculous, -hostxido.com'},
#  {'created_at': 'Wed Jul 24 01:00:02 +0000 2019',
#   'text': 'RT @AxBernardes: MATLAB é muito prático, mas tem horas que ele enche tanto o saco que dá vontade de migrar toda a pesquisa pra python. Aí s…'},
#  {'created_at': 'Wed Jul 24 01:00:03 +0000 2019',
#   'text': 'RT @ubuntu_sec: Episode 40 of the @Ubuntu #Security Podcast is live - covers the past 2 weeks security including @Docker, @zeromq, Squid, @…'},
#  {'created_at': 'Wed Jul 24 01:00:03 +0000 2019',
#   'text': 'This job opening may be your career booster =&gt; Big Data Systems Administrator https://t.co/PXisLmzBCy #bigdata #iot… https://t.co/B53qXkRCFG'},
#  {'created_at': 'Wed Jul 24 01:00:03 +0000 2019',
#   'text': 'RT @DTaC_BOT: Imagine how useful Python code would be for being a glazier. Langdon Winner might even say such a use would be unimaginative!'},
#  {'created_at': 'Wed Jul 24 01:00:03 +0000 2019',
#   'text': 'RT @richhinkle: This would be fun to try with process Historian data.  \nTime Series Decomposition &amp; Prediction in Python https://t.co/jm9Q3…'},
#  {'created_at': 'Wed Jul 24 01:00:04 +0000 2019',
#   'text': 'RT @pythonlangbot: Is there a 1-line solution to turn a scalar into a n-length array with the same value in each element https://t.co/YySfd…'},
#  {'created_at': 'Wed Jul 24 01:00:04 +0000 2019',
#   'text': 'RT @simizu706: 分析だけならRでいいと思います。ただ、最近の心理学実験のプログラムがPythonで動くものが多いです。その場合、Pythonができたほうがいいだろうな、と。そして…\n\n続きは質問箱へ (残り 49字) \n\n#peing #質問箱 https://t…'},
#  {'created_at': 'Wed Jul 24 01:00:05 +0000 2019',
#   'text': 'RT @blackcat_syka: 日本語学概論、突然pythonコード見せ始めてわろてる'},
#  {'created_at': 'Wed Jul 24 01:00:05 +0000 2019',
#   'text': 'RT @pythonlangbot: Is there a 1-line solution to turn a scalar into a n-length array with the same value in each element https://t.co/YySfd…'},
#  {'created_at': 'Wed Jul 24 01:00:05 +0000 2019',
#   'text': 'A big thank you to @RM_Furey for coming out and teaching a TVLI class about data! People are excited to use the bes… https://t.co/gjbrUWkNOn'},
#  {'created_at': 'Wed Jul 24 01:00:10 +0000 2019',
#   'text': 'All still avalable'},
#  {'created_at': 'Wed Jul 24 01:00:12 +0000 2019',
#   'text': "@ryanallred I think Observable https://t.co/pK3wB6JFJn can be embedded in any site, but then you're dealing with JS and not Python 😕"},
#  {'created_at': 'Wed Jul 24 01:00:12 +0000 2019',
#   'text': 'Review: Be afraid. Be very afraid of big data. The documentary ‘The Great Hack’ tells us why… https://t.co/1dIBEESmgX'},
#  {'created_at': 'Wed Jul 24 01:00:12 +0000 2019',
#   'text': 'Is Boris Johnson not a Monty python character?'},
#  {'created_at': 'Wed Jul 24 01:00:12 +0000 2019',
#   'text': 'ラズベリーパイより、7月24日10時0分の空模様と気温 25.625℃ #raspberrypi #python #fswebcam #photo #北海道 #オホーツク #イマソラ https://t.co/ytGOF6NgYS'},
#  {'created_at': 'Wed Jul 24 01:00:13 +0000 2019',
#   'text': '#EulerOS #2.0 SP2 : python-jinja2 (EulerOS-SA-2019-1722) https://t.co/zJH8Wh3phN #Nessus'},
#  {'created_at': 'Wed Jul 24 01:00:13 +0000 2019',
#   'text': 'RT @pythonlangbot: Is there a 1-line solution to turn a scalar into a n-length array with the same value in each element https://t.co/YySfd…'},
#  {'created_at': 'Wed Jul 24 01:00:15 +0000 2019',
#   'text': 'Hey did you know I was born at Studio Bas Sala ? They love Big Data too ! #BigData #StudioBasSala'},
#  {'created_at': 'Wed Jul 24 01:00:15 +0000 2019',
#   'text': 'Everyone needs to use @whispersystems #Signal right the fuck now.'},
#  {'created_at': 'Wed Jul 24 01:00:15 +0000 2019',
#   'text': 'This is the Big Data Furniture. I will be colleting the data of the #Dutch DesignWeek visitors. You can find me at… https://t.co/oAaWORkPmj'},
#  {'created_at': 'Wed Jul 24 01:00:15 +0000 2019',
#   'text': 'Data + Data + Data makes Big Data #BigData #DDW16'},
#  {'created_at': 'Wed Jul 24 01:00:18 +0000 2019',
#   'text': 'This AI Can Transform Your Photos Into A Renaissance Masterpiece https://t.co/JXvTjayNh8 #DeepLearning… https://t.co/0Fmxtk6L0L'},
#  {'created_at': 'Wed Jul 24 01:00:19 +0000 2019',
#   'text': 'RT @suin: Pythonって商標登録されてたんですね…。\n\n言語としての商標ではなく、セミナー等に限ってのもののようですが、公の財産とも言えるオープンソースのプロダクト名を商標登録しちゃうのってどうなんでしょう🤔\n\nサイトの注意書きを見る限り、競合他社のPython講座…'},
#  {'created_at': 'Wed Jul 24 01:00:19 +0000 2019',
#   'text': 'RT @Bradley_Dice: @EricJorgenson I wrote some guest lectures on Databases for a chemical engineering graduate course. It uses Python + SQLi…'},
#  {'created_at': 'Wed Jul 24 01:00:20 +0000 2019',
#   'text': 'RT @realpython: 🐍🎤 Python Community Interview With Mike Grouchy — https://t.co/t2WmtHWRro https://t.co/cYNTKjEc5O'},
#  {'created_at': 'Wed Jul 24 01:00:20 +0000 2019',
#   'text': 'RT @blackcat_syka: 日本語学概論、突然pythonコード見せ始めてわろてる'},
#  {'created_at': 'Wed Jul 24 01:00:21 +0000 2019',
#   'text': "RT @SBace6: @stonecold2050 Monty Python couldn't write a script this ridiculous. 😂☺️😂☺️😂"},
#  {'created_at': 'Wed Jul 24 01:00:26 +0000 2019',
#   'text': 'AVAILABLE: Python: 2 Manuscripts in 1 book : -  Python For... by Timothy C. Needham - https://t.co/fGSqrhtNJ1'},
#  {'created_at': 'Wed Jul 24 01:00:26 +0000 2019',
#   'text': '@HolyCarpSC @incendiate Oh big derp, I miss-read the frame data there.'},
#  {'created_at': 'Wed Jul 24 01:00:26 +0000 2019',
#   'text': 'RT @mattblaze: I have to say, Barr’s argument that the personal and commercial data protected by encryption isn’t all that important and th…'},
#  {'created_at': 'Wed Jul 24 01:00:27 +0000 2019',
#   'text': '#Spectrum My #InternetSpeed :\nPing: 44.305 ms\nDownload: 176.23 Mbit/s\nUpload: 11.06 Mbit/s\n#automagic #python #corporateaccountability'},
#  {'created_at': 'Wed Jul 24 01:00:28 +0000 2019',
#   'text': 'What is your story of being locked in a company with a bad or nonexistent data science culture, and how did you mak… https://t.co/xH72Doe6O9'},
#  {'created_at': 'Wed Jul 24 01:00:30 +0000 2019',
#   'text': 'RT @cloudpreacher: The Chief Data Officer role was created in response to Big Data as companies accumulated ever-growing stores of data, so…'},
#  {'created_at': 'Wed Jul 24 01:00:32 +0000 2019',
#   'text': '#Trending: How to get a job working with artificial intelligence/machine learning - The Next Web\n\n#pyton #python… https://t.co/5hvhupzF9g'},
#  {'created_at': 'Wed Jul 24 01:00:32 +0000 2019',
#   'text': '今回はPythonのwhile文について解説しました！\n\n繰り返し処理は非常に頻繁に使われる処理でもあるので、\n初心者も必ず覚えておいていただければと思います。\n\nぜひご一読ください！… https://t.co/8TU8mOpJsW'},
#  {'created_at': 'Wed Jul 24 01:00:32 +0000 2019',
#   'text': "RT @pujaarajan: @TheAmolWalvekar @wimlds Yes. Here's the link to RSVP: https://t.co/fQKNP0iFLN"},
#  {'created_at': 'Wed Jul 24 01:00:33 +0000 2019',
#   'text': 'RT @python_import: A range filter and median filter using python https://t.co/C48FyaWFi6 Design a basic filter using numpy library in pytho…'},
#  {'created_at': 'Wed Jul 24 01:00:33 +0000 2019',
#   'text': "@biopharmacaster OMG, you really don't understand the data.  These were good results.  On Pancreatic cancer, nothin… https://t.co/Fcqxq42Zgx"},
#  {'created_at': 'Wed Jul 24 01:00:34 +0000 2019',
#   'text': 'RT @DynamoBIM: Come explore what Dynamo Core release 2.2 has to offer in our latest blog post! The Python node gets some polish with specia…'},
#  {'created_at': 'Wed Jul 24 01:00:34 +0000 2019',
#   'text': 'Onboard in one week-3 months contract #Python programmer opportunity - [ ➡ https://t.co/TUiKHN7y4g ] #Robotics #AI… https://t.co/0EZxuZMAZX'},
#  {'created_at': 'Wed Jul 24 01:00:34 +0000 2019',
#   'text': "RT @emekaboris: You shouldn't miss this if you are in Port Harcourt.\n\nWe will discuss best practice and new technologies for Data Science,…"},
#  {'created_at': 'Wed Jul 24 01:00:35 +0000 2019',
#   'text': 'Our Python Pupil Activity Pack teaches the programming language of Python (used by Facebook, Instagram, NASA, Youtu… https://t.co/kjzBW0dUC1'},
#  {'created_at': 'Wed Jul 24 01:00:37 +0000 2019',
#   'text': 'RT @Deep_In_Depth: Deep learning distinguishes Alzheimer’s from normal cognition https://t.co/4oH4yJEPS3 #DeepLearning #MachineLearning #AI…'},
#  {'created_at': 'Wed Jul 24 01:00:38 +0000 2019',
#   'text': '@MisturSanjay Rabbit the brown swallowed the female python whole'},
#  {'created_at': 'Wed Jul 24 01:00:40 +0000 2019',
#   'text': 'Great work @MarkFredNubble @briancreagan!'},
#  {'created_at': 'Wed Jul 24 01:00:41 +0000 2019',
#   'text': 'How to keep track of tools and equipment. What data and systems do you need to keep track of your assets, machines,… https://t.co/BQvQbjhZ6N'},
#  {'created_at': 'Wed Jul 24 01:00:51 +0000 2019',
#   'text': 'Advanced Machine Learning with Basic Excel. #Analytics #Data #BusinessIntelligence #DataScience… https://t.co/Lf413d7Vwe'},
#  {'created_at': 'Wed Jul 24 01:00:53 +0000 2019',
#   'text': '10 Predictions For AI, Big Data, And Analytics In 2018 For many businesses, technology seems to cause more problems https://t.co/7oR8pCvTwO'},
#  {'created_at': 'Wed Jul 24 01:01:04 +0000 2019',
#   'text': 'RT @mattblaze: I have to say, Barr’s argument that the personal and commercial data protected by encryption isn’t all that important and th…'},
#  {'created_at': 'Wed Jul 24 01:01:06 +0000 2019',
#   'text': 'RT @Deep__AI: From the Machine Learning &amp; Data Science glossary: Anomaly Detection https://t.co/SLVG6qw87Y #SupportVectorMachine #AnomalyDe…'},
#  {'created_at': 'Wed Jul 24 01:01:06 +0000 2019',
#   'text': '@LucylleR Merci pour m\'avoir mis un sketch des monty python dans la gueule grace à ta blague!\n"Sit on my face and t… https://t.co/OuaEmQytVN'},
#  {'created_at': 'Wed Jul 24 01:01:09 +0000 2019',
#   'text': 'Deep learning distinguishes Alzheimer’s from normal cognition https://t.co/GbdR5bj4is #DeepLearning… https://t.co/Lj81GpRnuk'},
#  {'created_at': 'Wed Jul 24 01:01:12 +0000 2019',
#   'text': 'Causality is a very flawed practice...how does Big Data predict?\nhttps://t.co/oC8nufs1CD'},
#  {'created_at': 'Wed Jul 24 01:01:14 +0000 2019',
#   'text': "RT @DaniellesCave: Big new research project from @ASPI_ICPC we've just put online. We combined open-source data with the collection and ana…"},
#  {'created_at': 'Wed Jul 24 01:01:16 +0000 2019',
#   'text': '@therealmonaIisa Python is a great beginner friendly language and it is widely used in a variety of fields.'},
#  {'created_at': 'Wed Jul 24 01:01:18 +0000 2019',
#   'text': 'RT @mattblaze: I have to say, Barr’s argument that the personal and commercial data protected by encryption isn’t all that important and th…'},
#  {'created_at': 'Wed Jul 24 01:01:24 +0000 2019',
#   'text': 'RT @LouisVillacci: A big thank you to @RM_Furey for coming out and teaching a TVLI class about data! People are excited to use the best dat…'},
#  {'created_at': 'Wed Jul 24 01:01:27 +0000 2019',
#   'text': '@nando_nurhadi @yuswohady @jams_ksei @fitriyanojik @bro_danang @pirenaningsih Mungkin ini asal muasal istilah big d… https://t.co/n5jZHoa49i'},
#  {'created_at': 'Wed Jul 24 01:01:28 +0000 2019',
#   'text': 'Job : AI &amp; MACHINE LEARNING ENGINEER\nLocation: Plaza Damas 3, Kuala Lumpur\nAt least 2 years of experience in AI and… https://t.co/khG6D6rIEV'},
#  {'created_at': 'Wed Jul 24 01:01:35 +0000 2019',
#   'text': 'RT @KirkDBorne: 5 Books on #AI and #MachineLearning to get in 2019: https://t.co/VYFynmubzO #abdsc #DataScience #BigData #Python #Reinforce…'},
#  {'created_at': 'Wed Jul 24 01:01:37 +0000 2019',
#   'text': 'RT @mattblaze: I have to say, Barr’s argument that the personal and commercial data protected by encryption isn’t all that important and th…'},
#  {'created_at': 'Wed Jul 24 01:01:39 +0000 2019',
#   'text': 'Python for Data Science: 8 Concepts You May Have Forgotten\n\n☞ https://t.co/6cQlkYvJVe\n\n#python #programming https://t.co/Delke1TKSd'},
#  {'created_at': 'Wed Jul 24 01:01:45 +0000 2019',
#   'text': 'RT @vakibs: My mother tongue Telugu will disappear in a few decades. It already became a pidgin of English. On TV, barely anyone can speak…'},
#  {'created_at': 'Wed Jul 24 01:01:49 +0000 2019',
#   'text': 'RT @sntripathi1: Businesses are changing the way they engage with customers and manage customers &amp; customer service teams by driving innova…'},
#  {'created_at': 'Wed Jul 24 01:01:51 +0000 2019',
#   'text': 'RT @Rbloggers: Learning Data Science: Understanding and Using k-means Clustering  {https://t.co/vVltNVZO0v} #rstats #DataScience'},
#  {'created_at': 'Wed Jul 24 01:01:59 +0000 2019',
#   'text': 'RT @mattblaze: I have to say, Barr’s argument that the personal and commercial data protected by encryption isn’t all that important and th…'},
#  {'created_at': 'Wed Jul 24 01:02:01 +0000 2019',
#   'text': 'Download The Art of Invisibility: The World&amp;#39;s Most Famous Hacker Teaches You How to Be Safe in the Age of Big B… https://t.co/ctXsABnWjX'},
#  {'created_at': 'Wed Jul 24 01:02:04 +0000 2019',
#   'text': 'RT @himpatani: วิชาวิทยการคำนวณ วิชาใหม่สำหรับเด็กไทยและครูไทยทุกคน\n\n#วิทยาการคำนวณ #python\nhttps://t.co/wJJgi2GWmg'}]

# %%
# Importando o módulo Pandas para trabalhar com datasets em Python
import pandas as pd

# %%
# Criando um dataframe a partir do dataset 
df = pd.DataFrame(dataset)

# %%
# Imprimindo o dataframe
df
# Out:
#                         created_at  \
# 0   Wed Jul 24 00:59:32 +0000 2019
# 1   Wed Jul 24 00:59:35 +0000 2019
# 2   Wed Jul 24 00:59:36 +0000 2019
# 3   Wed Jul 24 00:59:38 +0000 2019
# 4   Wed Jul 24 00:59:40 +0000 2019
# 5   Wed Jul 24 00:59:47 +0000 2019
# 6   Wed Jul 24 00:59:49 +0000 2019
# 7   Wed Jul 24 00:59:51 +0000 2019
# 8   Wed Jul 24 00:59:53 +0000 2019
# 9   Wed Jul 24 00:59:54 +0000 2019
# 10  Wed Jul 24 01:00:00 +0000 2019
# 11  Wed Jul 24 01:00:02 +0000 2019
# 12  Wed Jul 24 01:00:02 +0000 2019
# 13  Wed Jul 24 01:00:03 +0000 2019
# 14  Wed Jul 24 01:00:03 +0000 2019
# 15  Wed Jul 24 01:00:03 +0000 2019
# 16  Wed Jul 24 01:00:03 +0000 2019
# 17  Wed Jul 24 01:00:04 +0000 2019
# 18  Wed Jul 24 01:00:04 +0000 2019
# 19  Wed Jul 24 01:00:05 +0000 2019
# 20  Wed Jul 24 01:00:05 +0000 2019
# 21  Wed Jul 24 01:00:05 +0000 2019
# 22  Wed Jul 24 01:00:10 +0000 2019
# 23  Wed Jul 24 01:00:12 +0000 2019
# 24  Wed Jul 24 01:00:12 +0000 2019
# 25  Wed Jul 24 01:00:12 +0000 2019
# 26  Wed Jul 24 01:00:12 +0000 2019
# 27  Wed Jul 24 01:00:13 +0000 2019
# 28  Wed Jul 24 01:00:13 +0000 2019
# 29  Wed Jul 24 01:00:15 +0000 2019
# ..                             ...
# 50  Wed Jul 24 01:00:34 +0000 2019
# 51  Wed Jul 24 01:00:34 +0000 2019
# 52  Wed Jul 24 01:00:34 +0000 2019
# 53  Wed Jul 24 01:00:35 +0000 2019
# 54  Wed Jul 24 01:00:37 +0000 2019
# 55  Wed Jul 24 01:00:38 +0000 2019
# 56  Wed Jul 24 01:00:40 +0000 2019
# 57  Wed Jul 24 01:00:41 +0000 2019
# 58  Wed Jul 24 01:00:51 +0000 2019
# 59  Wed Jul 24 01:00:53 +0000 2019
# 60  Wed Jul 24 01:01:04 +0000 2019
# 61  Wed Jul 24 01:01:06 +0000 2019
# 62  Wed Jul 24 01:01:06 +0000 2019
# 63  Wed Jul 24 01:01:09 +0000 2019
# 64  Wed Jul 24 01:01:12 +0000 2019
# 65  Wed Jul 24 01:01:14 +0000 2019
# 66  Wed Jul 24 01:01:16 +0000 2019
# 67  Wed Jul 24 01:01:18 +0000 2019
# 68  Wed Jul 24 01:01:24 +0000 2019
# 69  Wed Jul 24 01:01:27 +0000 2019
# 70  Wed Jul 24 01:01:28 +0000 2019
# 71  Wed Jul 24 01:01:35 +0000 2019
# 72  Wed Jul 24 01:01:37 +0000 2019
# 73  Wed Jul 24 01:01:39 +0000 2019
# 74  Wed Jul 24 01:01:45 +0000 2019
# 75  Wed Jul 24 01:01:49 +0000 2019
# 76  Wed Jul 24 01:01:51 +0000 2019
# 77  Wed Jul 24 01:01:59 +0000 2019
# 78  Wed Jul 24 01:02:01 +0000 2019
# 79  Wed Jul 24 01:02:04 +0000 2019
#
#                                                  text
# 0   Mi nuh like hypocrite an bad mine people data ...
# 1   RT @WesternBhagwa: @SulagnaDash6 Reminded me o...
# 2   @TheAmolWalvekar @wimlds Yes. Here's the link ...
# 3   RT @KingMidasAu1: $SNMN massive inflection of ...
# 4   RT @jimbobbennett: Well this is a no brainer -...
# 5   RT @zakkie_jp: “AIエバンジェリスト、ＡＩ 駆動ビジネス、Python、Ag...
# 6   RT @odsc: MIT Press and Harvard Data Science I...
# 7   RT @simizu706: 分析だけならRでいいと思います。ただ、最近の心理学実験のプログ...
# 8   @QL611 @hrenee80 So I have a multi-colored Bal...
# 9   Only 5 months 7 days 23 hours left until Pytho...
# 10  【2018年Google Trends調べ】\n最もググられたプログラミング言語ベスト10\...
# 11  Hosting (Hospedaje Web) Premium 99.99% Uptime,...
# 12  RT @AxBernardes: MATLAB é muito prático, mas t...
# 13  RT @ubuntu_sec: Episode 40 of the @Ubuntu #Sec...
# 14  This job opening may be your career booster =&...
# 15  RT @DTaC_BOT: Imagine how useful Python code w...
# 16  RT @richhinkle: This would be fun to try with ...
# 17  RT @pythonlangbot: Is there a 1-line solution ...
# 18  RT @simizu706: 分析だけならRでいいと思います。ただ、最近の心理学実験のプログ...
# 19     RT @blackcat_syka: 日本語学概論、突然pythonコード見せ始めてわろてる
# 20  RT @pythonlangbot: Is there a 1-line solution ...
# 21  A big thank you to @RM_Furey for coming out an...
# 22                                 All still avalable
# 23  @ryanallred I think Observable https://t.co/pK...
# 24  Review: Be afraid. Be very afraid of big data....
# 25     Is Boris Johnson not a Monty python character?
# 26  ラズベリーパイより、7月24日10時0分の空模様と気温 25.625℃ #raspberry...
# 27  #EulerOS #2.0 SP2 : python-jinja2 (EulerOS-SA-...
# 28  RT @pythonlangbot: Is there a 1-line solution ...
# 29  Hey did you know I was born at Studio Bas Sala...
# ..                                                ...
# 50  RT @DynamoBIM: Come explore what Dynamo Core r...
# 51  Onboard in one week-3 months contract #Python ...
# 52  RT @emekaboris: You shouldn't miss this if you...
# 53  Our Python Pupil Activity Pack teaches the pro...
# 54  RT @Deep_In_Depth: Deep learning distinguishes...
# 55  @MisturSanjay Rabbit the brown swallowed the f...
# 56          Great work @MarkFredNubble @briancreagan!
# 57  How to keep track of tools and equipment. What...
# 58  Advanced Machine Learning with Basic Excel. #A...
# 59  10 Predictions For AI, Big Data, And Analytics...
# 60  RT @mattblaze: I have to say, Barr’s argument ...
# 61  RT @Deep__AI: From the Machine Learning &amp; ...
# 62  @LucylleR Merci pour m'avoir mis un sketch des...
# 63  Deep learning distinguishes Alzheimer’s from n...
# 64  Causality is a very flawed practice...how does...
# 65  RT @DaniellesCave: Big new research project fr...
# 66  @therealmonaIisa Python is a great beginner fr...
# 67  RT @mattblaze: I have to say, Barr’s argument ...
# 68  RT @LouisVillacci: A big thank you to @RM_Fure...
# 69  @nando_nurhadi @yuswohady @jams_ksei @fitriyan...
# 70  Job : AI &amp; MACHINE LEARNING ENGINEER\nLoca...
# 71  RT @KirkDBorne: 5 Books on #AI and #MachineLea...
# 72  RT @mattblaze: I have to say, Barr’s argument ...
# 73  Python for Data Science: 8 Concepts You May Ha...
# 74  RT @vakibs: My mother tongue Telugu will disap...
# 75  RT @sntripathi1: Businesses are changing the w...
# 76  RT @Rbloggers: Learning Data Science: Understa...
# 77  RT @mattblaze: I have to say, Barr’s argument ...
# 78  Download The Art of Invisibility: The World&am...
# 79  RT @himpatani: วิชาวิทยการคำนวณ วิชาใหม่สำหรับ...
#
# [80 rows x 2 columns]

# %%
# Importando o módulo Scikit Learn
from sklearn.feature_extraction.text import CountVectorizer

# %%
# Usando o método CountVectorizer para criar uma matriz de documentos
cv = CountVectorizer()
count_matrix = cv.fit_transform(df.text)

# %%
# Contando o número de ocorrências das principais palavras em nosso dataset
word_count = pd.DataFrame(cv.get_feature_names(), columns=["word"])
word_count["count"] = count_matrix.sum(axis=0).tolist()[0]
word_count = word_count.sort_values("count", ascending=False).reset_index(drop=True)
word_count[:50]
# Out:
#            word  count
# 0         https     50
# 1            co     47
# 2            rt     39
# 3          data     36
# 4           the     35
# 5        python     32
# 6           and     28
# 7            to     25
# 8            in     19
# 9            of     16
# 10          big     15
# 11         with     13
# 12           is     12
# 13          you     12
# 14         that     10
# 15          for      9
# 16           be      9
# 17           ai      8
# 18         this      8
# 19           by      8
# 20          how      8
# 21         have      7
# 22     learning      7
# 23      science      7
# 24          all      6
# 25          say      6
# 26          isn      5
# 27         from      5
# 28   encryption      5
# 29           on      5
# 30    protected      5
# 31           th      5
# 32   commercial      5
# 33         barr      5
# 34     personal      5
# 35          amp      5
# 36     argument      5
# 37    mattblaze      5
# 38    important      5
# 39        there      4
# 40          are      4
# 41         into      4
# 42         your      4
# 43      machine      4
# 44  datascience      4
# 45      bigdata      4
# 46          use      4
# 47          can      4
# 48           we      3
# 49        value      3

# %% [markdown]
# # Fim

# %% [markdown]
# ### Obrigado - Data Science Academy - <a href="http://facebook.com/dsacademybr">facebook.com/dsacademybr</a>
