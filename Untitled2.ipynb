# %%
import pandas as pd

# %%
data = pd.read_csv('StudentsPerformance.csv')

# %%
data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
grouped = data[['math score', 'reading score', 'writing score']].groupby(data['gender'])
grouped.mean()
# Out:
#         math score  reading score  writing score
# gender
# female   63.633205      72.608108      72.467181
# male     68.728216      65.473029      63.311203

# %%
grouped_keys = data[['math score', 'reading score', 'writing score']].groupby([data['gender'], data['test preparation course']])
grouped_keys.mean()
# Out:
#                                 math score  reading score  writing score
# gender test preparation course
# female completed                 67.195652      77.375000      78.793478
#        none                      61.670659      69.982036      68.982036
# male   completed                 72.339080      70.212644      69.793103
#        none                      66.688312      62.795455      59.649351

# %%
grouped_keys.describe()
# Out:
#                                math score                                     \
#                                     count       mean        std   min    25%
# gender test preparation course
# female completed                    184.0  67.195652  14.244346  23.0  58.75
#        none                         334.0  61.670659  15.818013   0.0  52.00
# male   completed                    174.0  72.339080  14.221817  39.0  62.00
#        none                         308.0  66.688312  14.049016  27.0  57.75
#
#                                                   reading score             \
#                                  50%   75%    max         count       mean
# gender test preparation course
# female completed                67.0  76.0   99.0         184.0  77.375000
#        none                     62.0  73.0  100.0         334.0  69.982036
# male   completed                73.0  82.0  100.0         174.0  70.212644
#        none                     67.0  76.0   97.0         308.0  62.795455
#
#                                 ...              writing score             \
#                                 ...   75%    max         count       mean
# gender test preparation course  ...
# female completed                ...  86.0  100.0         184.0  78.793478
#        none                     ...  80.0  100.0         334.0  68.982036
# male   completed                ...  81.0  100.0         174.0  69.793103
#        none                     ...  73.0   96.0         308.0  59.649351
#
#
#                                       std   min    25%   50%    75%    max
# gender test preparation course
# female completed                12.240788  36.0  72.00  79.0  87.25  100.0
#        none                     15.016497  10.0  60.00  70.0  79.00  100.0
# male   completed                12.992339  38.0  60.25  70.0  79.00  100.0
#        none                     13.405737  15.0  51.00  60.0  69.00   92.0
#
# [4 rows x 24 columns]

# %%
grouped = data.groupby(['race/ethnicity', 'parental level of education'])
grouped_math = grouped['math score']
grouped_math.agg('mean')
# Out:
# race/ethnicity  parental level of education
# group A         associate's degree             61.000000
#                 bachelor's degree              67.166667
#                 high school                    60.444444
#                 master's degree                57.666667
#                 some college                   63.888889
#                 some high school               58.916667
# group B         associate's degree             66.097561
#                 bachelor's degree              69.300000
#                 high school                    59.791667
#                 master's degree                67.166667
#                 some college                   63.189189
#                 some high school               61.815789
# group C         associate's degree             66.730769
#                 bachelor's degree              68.150000
#                 high school                    60.906250
#                 master's degree                67.052632
#                 some college                   65.130435
#                 some high school               60.551020
# group D         associate's degree             67.600000
#                 bachelor's degree              67.571429
#                 high school                    62.863636
#                 master's degree                72.521739
#                 some college                   68.731343
#                 some high school               66.760000
# group E         associate's degree             74.897436
#                 bachelor's degree              76.555556
#                 high school                    70.772727
#                 master's degree                74.625000
#                 some college                   73.828571
#                 some high school               72.111111
# Name: math score, dtype: float64

# %%
grouped_math.get_group(("group A", "bachelor's degree"))
# Out:
# 77     80
# 129    51
# 151    77
# 365    49
# 379    66
# 464    75
# 571    91
# 697    59
# 702    87
# 705    62
# 816    45
# 832    64
# Name: math score, dtype: int64

# %%
def stats(group):
    return {'min': group.min(), 'max': group.max(), 'count':                       
            group.count(), 'mean': group.mean()}

# %%
bins = [0, 25, 50, 75, 100]
group_names = ['Baixo', 'Razoavel', 'Bom', 'Excelente']
data['categorias'] = pd.cut(data['reading score'], bins, labels=group_names)

# %%
data['reading score'].groupby(data['categorias']).apply(stats).unstack()
# Out:
#             count    max       mean   min
# categorias
# Baixo         4.0   24.0  22.000000  17.0
# Razoavel     93.0   50.0  43.064516  26.0
# Bom         559.0   75.0  64.352415  51.0
# Excelente   344.0  100.0  84.601744  76.0

# %%
bdmg = pd.read_excel('Planilha Teste.xlsx', index_col=0)

# %%
bdmg.head()
# Out:
#           Código do Cliente                                      Cliente  \
# Processo
# 301222               194481               VMI SISTEMAS DE SEGURANCA LTDA
# 314900                76675      SANKHYA JIVA TECNOLOGIA E INOVACAO LTDA
# 315414               243154  PORTO MINEIRO DE GRAOS ARMAZENS GERAIS LTDA
# 316220               347791                 MIB - MINERACAO IBIRITE LTDA
# 316280               289985                             CASA MATTOS LTDA
#
#           Data Bal.  Geração média de caixa Último Balanço > 1460 dias  \
# Processo
# 301222        42369            1.581120e+07                        Não
# 314900        42369            3.406310e+06                        Não
# 315414        42369            1.304301e+06                        Não
# 316220        42369            4.895594e+07                        Não
# 316280        42369            1.661348e+06                        Não
#
#           ROB para data base  Soma 3 últimos Lucros Líquidos   \
# Processo
# 301222           64267131.00                     4.550328e+07
# 314900           43658059.47                     9.760290e+06
# 315414           76517470.68                     2.561364e+06
# 316220           77040316.69                     1.124183e+08
# 316280           62858053.14                     4.360515e+06
#
#           Patrimônio Líquido - Última DF Risco  Dívida Líquida / Ebitda  \
# Processo
# 301222                       35399758.00    B                  0.809632
# 314900                        6409570.42    AA                -0.007533
# 315414                        5865465.17    A                  0.755096
# 316220                       26317086.76    A                  0.508548
# 316280                        9198441.64    A                  0.602347
#
#           Dívida / ROB       Dívida  Aplicações de Liquidez Imediata  \
# Processo
# 301222        0.125294       542545                       1166556.00
# 314900        0.050890  1.75264e+06                       2281422.25
# 315414        0.065672       946887                       2330406.30
# 316220        0.167471  6.41268e+06                        125000.01
# 316280        0.046938  2.37625e+06                       1281387.81
#
#          Nível BACEN Possui Audit.Externa? Audit. Big 4
# Processo
# 301222            B                      N          NaN
# 314900            AA                     N          NaN
# 315414            A                      N          NaN
# 316220            A                      N          NaN
# 316280            A                      N          NaN

# %%
div = 10**6
bins = [-300*div,0, 30*div, 40*div, 50*div, 60*div]
group_names = ['<0', '0 |-- 30', '30 |-- 40', '40 |-- 50', '50 |-- 60']
bdmg['categorias']=pd.cut(bdmg['Geração média de caixa'], bins, labels= group_names)

# %%
from pandas import DataFrame
DataFrame(bdmg, columns=['Geração média de caixa', 'categorias'])
# Out:
#           Geração média de caixa categorias
# Processo
# 301222              1.581120e+07   0 |-- 30
# 314900              3.406310e+06   0 |-- 30
# 315414              1.304301e+06   0 |-- 30
# 316220              4.895594e+07  40 |-- 50
# 316280              1.661348e+06   0 |-- 30
# 316863              9.960985e+04   0 |-- 30
# 317479              7.584096e+06   0 |-- 30
# 317864              3.015137e+06   0 |-- 30
# 318192              2.427879e+06   0 |-- 30
# 318421             -4.184267e+07         <0
# 318689              6.449371e+05   0 |-- 30
# 318945              3.032840e+05   0 |-- 30
# 319032              8.615654e+06   0 |-- 30
# 320012              9.974180e+06   0 |-- 30
# 320158              3.297977e+07  30 |-- 40
# 320453             -9.199135e+05         <0
# 320993              1.988350e+06   0 |-- 30
# 322145              6.286644e+06   0 |-- 30
# 322471              8.361825e+04   0 |-- 30
# 322741              1.117832e+06   0 |-- 30
# 322763              2.101217e+06   0 |-- 30
# 323156              1.772450e+06   0 |-- 30
# 323177              2.098644e+06   0 |-- 30
# 323447              2.341522e+06   0 |-- 30
# 323689              6.625319e+06   0 |-- 30
# 324017              2.863293e+05   0 |-- 30
# 324020              1.573982e+06   0 |-- 30
# 324055              2.873667e+06   0 |-- 30
# 324189              2.311257e+06   0 |-- 30
# 324486              1.941850e+07   0 |-- 30
# ...                          ...        ...
# 417522              5.670200e+04   0 |-- 30
# 417729              1.708014e+06   0 |-- 30
# 417824              8.348302e+06   0 |-- 30
# 417872              4.204945e+05   0 |-- 30
# 418991              1.421776e+07   0 |-- 30
# 418996              1.245847e+07   0 |-- 30
# 419248              1.013496e+07   0 |-- 30
# 419497              3.904557e+06   0 |-- 30
# 419585              1.112325e+06   0 |-- 30
# 419911              5.161043e+06   0 |-- 30
# 420282              8.904484e+06   0 |-- 30
# 420354              8.426896e+05   0 |-- 30
# 420577              4.378262e+06   0 |-- 30
# 420845              2.264523e+06   0 |-- 30
# 421040              3.661195e+06   0 |-- 30
# 421213              3.918754e+06   0 |-- 30
# 421355              1.486388e+06   0 |-- 30
# 421367              7.714374e+06   0 |-- 30
# 421922              2.016388e+05   0 |-- 30
# 422347              1.485030e+06   0 |-- 30
# 422689              1.039319e+06   0 |-- 30
# 424049              9.708318e+05   0 |-- 30
# 424573              3.589366e+06   0 |-- 30
# 424827              6.178433e+05   0 |-- 30
# 425435              9.374660e+05   0 |-- 30
# 426420              2.071990e+07   0 |-- 30
# 426703              3.073073e+06   0 |-- 30
# 427783              5.761468e+06   0 |-- 30
# 428959             -9.976075e+05         <0
# 433568              4.390959e+06   0 |-- 30
#
# [360 rows x 2 columns]

# %%
bdmg['Geração média de caixa'].groupby(bdmg['categorias']).apply(stats).unstack()
# Out:
#             count           max          mean           min
# categorias
# <0           19.0 -1.352767e+04 -4.825602e+06 -4.184267e+07
# 0 |-- 30    335.0  2.716766e+07  3.717095e+06  1.332833e+04
# 30 |-- 40     3.0  3.793100e+07  3.388202e+07  3.073529e+07
# 40 |-- 50     2.0  4.895594e+07  4.762430e+07  4.629267e+07
# 50 |-- 60     0.0           NaN           NaN           NaN

# %%
bdmg['Geração média de caixa'].hist()
plt.show()

# %%
import matplotlib.pyplot as plt

# %%
plt.bar('Geração média de caixa', label = 'Barras', color = 'r')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-4abd2b10decb> in <module>
# ----> 1 plt.bar('Geração média de caixa', label = 'Barras', color = 'r')
#       2 plt.legend()
#       3 plt.show()
#
# TypeError: bar() missing 1 required positional argument: 'height'
